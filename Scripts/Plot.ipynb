# %%
# !pip install hvplot pandas pyarrow

# %%
import pandas as pd
import hvplot.pandas

import holoviews as hv
hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='c944723f-95ab-4bfc-aa27-0db1051c1d1f'>
#   <div id="f22f9881-c3b1-4507-ad1f-6869db435bfe" data-root-id="c944723f-95ab-4bfc-aa27-0db1051c1d1f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
import glob

files=glob.glob("/home/serg/Documentos/Proyecto/Files/Parquet/*.parquet")

df=pd.concat([pd.read_parquet(f,columns=[' Label']) for f in files],ignore_index=True)

# %%
import glob

file="/home/serg/Documentos/Proyecto/Files/Training/test.parquet"

df=pd.read_parquet(file,columns=[' Label'])

# %%
counts=df[' Label'].value_counts().reset_index()
counts.columns=['Label','Count']

# %%
counts.hvplot.bar(
    x='Label',
    y='Count',
    title="Distribución de Labels",
    rot=45
)
# Out:
# :Bars   [Label]   (Count)
