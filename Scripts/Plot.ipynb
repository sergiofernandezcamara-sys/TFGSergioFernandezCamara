# %%
# !pip install hvplot pandas pyarrow
# Out:
# Collecting hvplot
#   Downloading hvplot-0.12.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pandas in ./venv/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: pyarrow in ./venv/lib/python3.12/site-packages (23.0.1)
# Collecting bokeh>=3.1 (from hvplot)
#   Downloading bokeh-3.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting colorcet>=2 (from hvplot)
#   Downloading colorcet-3.1.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting holoviews>=1.19.0 (from hvplot)
#   Downloading holoviews-1.22.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21 in ./venv/lib/python3.12/site-packages (from hvplot) (2.4.3)
# Requirement already satisfied: packaging in ./venv/lib/python3.12/site-packages (from hvplot) (26.0)
# Collecting panel>=1.0 (from hvplot)
#   Downloading panel-1.8.10-py3-none-any.whl.metadata (15 kB)
# Collecting param<3.0,>=1.12.0 (from hvplot)
#   Downloading param-2.3.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: Jinja2>=2.9 in ./venv/lib/python3.12/site-packages (from bokeh>=3.1->hvplot) (3.1.6)
# Collecting contourpy>=1.2 (from bokeh>=3.1->hvplot)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting narwhals>=1.13 (from bokeh>=3.1->hvplot)
#   Downloading narwhals-2.19.0-py3-none-any.whl.metadata (14 kB)
# Collecting pillow>=7.1.0 (from bokeh>=3.1->hvplot)
#   Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Requirement already satisfied: PyYAML>=3.10 in ./venv/lib/python3.12/site-packages (from bokeh>=3.1->hvplot) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in ./venv/lib/python3.12/site-packages (from bokeh>=3.1->hvplot) (6.5.5)
# Collecting xyzservices>=2021.09.1 (from bokeh>=3.1->hvplot)
#   Downloading xyzservices-2026.3.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting pyviz-comms>=2.1 (from holoviews>=1.19.0->hvplot)
#   Downloading pyviz_comms-3.0.6-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: bleach in ./venv/lib/python3.12/site-packages (from panel>=1.0->hvplot) (6.3.0)
# Collecting linkify-it-py (from panel>=1.0->hvplot)
#   Downloading linkify_it_py-2.1.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting markdown (from panel>=1.0->hvplot)
#   Downloading markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting markdown-it-py (from panel>=1.0->hvplot)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting mdit-py-plugins (from panel>=1.0->hvplot)
#   Downloading mdit_py_plugins-0.5.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests in ./venv/lib/python3.12/site-packages (from panel>=1.0->hvplot) (2.33.1)
# Requirement already satisfied: tqdm in ./venv/lib/python3.12/site-packages (from panel>=1.0->hvplot) (4.67.3)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.12/site-packages (from panel>=1.0->hvplot) (4.15.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.12/site-packages (from Jinja2>=2.9->bokeh>=3.1->hvplot) (3.0.3)
# Requirement already satisfied: webencodings in ./venv/lib/python3.12/site-packages (from bleach->panel>=1.0->hvplot) (0.5.1)
# Collecting uc-micro-py (from linkify-it-py->panel>=1.0->hvplot)
#   Downloading uc_micro_py-2.0.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py->panel>=1.0->hvplot)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests->panel>=1.0->hvplot) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests->panel>=1.0->hvplot) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.12/site-packages (from requests->panel>=1.0->hvplot) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in ./venv/lib/python3.12/site-packages (from requests->panel>=1.0->hvplot) (2026.2.25)
# Downloading hvplot-0.12.2-py3-none-any.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.6/180.6 kB 1.0 MB/s eta 0:00:001.4 MB/s eta 0:00:01
# Downloading bokeh-3.9.0-py3-none-any.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading colorcet-3.1.0-py3-none-any.whl (260 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.3/260.3 kB 1.2 MB/s eta 0:00:000:00:01m eta 0:00:01
# Downloading holoviews-1.22.1-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 2.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading panel-1.8.10-py3-none-any.whl (30.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading param-2.3.3-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 3.6 MB/s eta 0:00:006 MB/s eta 0:00:01
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 1.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading narwhals-2.19.0-py3-none-any.whl (446 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.0/447.0 kB 1.5 MB/s eta 0:00:000:00:010:00:01:01
# Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 2.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading pyviz_comms-3.0.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.3/84.3 kB 1.7 MB/s eta 0:00:002.7 MB/s eta 0:00:01
# Downloading xyzservices-2026.3.0-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.1/94.1 kB 1.8 MB/s eta 0:00:000:00:01
# Downloading linkify_it_py-2.1.0-py3-none-any.whl (19 kB)
# Downloading markdown-3.10.2-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.2/108.2 kB 773.6 kB/s eta 0:00:0031m1.3 MB/s eta 0:00:01
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 kB 1.9 MB/s eta 0:00:0061.3 MB/s eta 0:00:01
# Downloading mdit_py_plugins-0.5.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 795.8 kB/s eta 0:00:001m166.4 MB/s eta 0:00:01
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading uc_micro_py-2.0.0-py3-none-any.whl (6.4 kB)
# Installing collected packages: xyzservices, uc-micro-py, pillow, param, narwhals, mdurl, markdown, contourpy, colorcet, pyviz-comms, markdown-it-py, linkify-it-py, bokeh, mdit-py-plugins, panel, holoviews, hvplot
# Successfully installed bokeh-3.9.0 colorcet-3.1.0 contourpy-1.3.3 holoviews-1.22.1 hvplot-0.12.2 linkify-it-py-2.1.0 markdown-3.10.2 markdown-it-py-4.0.0 mdit-py-plugins-0.5.0 mdurl-0.1.2 narwhals-2.19.0 panel-1.8.10 param-2.3.3 pillow-12.2.0 pyviz-comms-3.0.6 uc-micro-py-2.0.0 xyzservices-2026.3.0

# %%
import pandas as pd
import hvplot.pandas

import holoviews as hv
hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='b24b06e2-ac34-4cc2-8eb3-59d6bd429aa9'>
#   <div id="c0bbcc37-7137-4a74-8fe0-50223a59663e" data-root-id="b24b06e2-ac34-4cc2-8eb3-59d6bd429aa9" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"15f77781-9376-4f94-836a-8adc9e81e806":{"version":"3.9.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"8312cd25-b191-4094-b425-6af53c9d7ac3","attributes":{"notifications":{"type":"object","name":"Notifications","id":"ff8a6797-2aa0-4e8a-9a5d-dab6d4ca1ac7"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"b24b06e2-ac34-4cc2-8eb3-59d6bd429aa9"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"25a881d4-8c69-459a-bb0e-21fd405a0d9c","attributes":{"plot_id":"b24b06e2-ac34-4cc2-8eb3-59d6bd429aa9","comm_id":"2089782979e44268936041e5c7d7e4b4","client_comm_id":"5d77160707714743a5d8585401b851cd"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"15f77781-9376-4f94-836a-8adc9e81e806","roots":{"b24b06e2-ac34-4cc2-8eb3-59d6bd429aa9":"c0bbcc37-7137-4a74-8fe0-50223a59663e"},"root_ids":["b24b06e2-ac34-4cc2-8eb3-59d6bd429aa9"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
import glob

files=glob.glob("/home/serg/Documentos/Proyecto/Files/Parquet/*.parquet")

df=pd.concat([pd.read_parquet(f,columns=[' Label']) for f in files],ignore_index=True)

# %%
counts=df[' Label'].value_counts().reset_index()
counts.columns=['Label','Count']

# %%
counts.hvplot.bar(
    x='Label',
    y='Count',
    title="Distribución de Labels",
    rot=45
)
# Out:
# :Bars   [Label]   (Count)
