# %%
# !pip install pandas numpy scikit-learn keras tensorflow

# %%
import sys,platform
print(sys.executable)
print(sys.version)
print(platform.platform())
# Out:
# /home/serg/Documentos/Proyecto/Code/venv/bin/python
# 3.12.3 (main, Mar  3 2026, 12:15:18) [GCC 13.3.0]
# Linux-6.17.0-20-generic-x86_64-with-glibc2.39

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras import layers

# %%
train_df=pd.read_parquet("/home/serg/Documentos/Proyecto/Files/Training/train.parquet")
val_df=pd.read_parquet("/home/serg/Documentos/Proyecto/Files/Training/val.parquet")
test_df=pd.read_parquet("/home/serg/Documentos/Proyecto/Files/Training/test.parquet")

# %%
x_train=train_df.drop(columns=["LabelBin"]).astype("float32").to_numpy()
y_train=train_df["LabelBin"].astype("float32").to_numpy()

x_val=val_df.drop(columns=["LabelBin"]).astype("float32").to_numpy()
y_val=val_df["LabelBin"].astype("float32").to_numpy()

x_test=test_df.drop(columns=["LabelBin"]).astype("float32").to_numpy()
y_test=test_df["LabelBin"].astype("float32").to_numpy()

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_val=scaler.transform(x_val)
x_test=scaler.transform(x_test)

# %%
model=keras.Sequential([
    keras.Input(shape=(x_train.shape[1])),
    layers.Dense(64,activation="relu"),
    layers.Dense(32,activation="relu"),
    layers.Dense(1,activation="sigmoid")
])
